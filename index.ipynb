# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
from bs4 import BeautifulSoup
import requests
import re
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
from IPython.display import Image, HTML

# %%
#Load the https://www.residentadvisor.net/events page in your browser.
html_page = requests.get('https://www.residentadvisor.net/events/us/seattle') 
#Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') 
#Pass the page contents to beautiful soup for parsing

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in Seattle, United States of America
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, seattle, united, states, america" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=ATv7yC5anBBrxJoYdSr-DqUPyab_mqaaXHG0qxMzlYI1" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=qgpSmyPbylOKeJFqy2yvCrTgAsw9yQYcJtLKS_vPO6s1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=3qaUNnKRH_PXCPLvCCsp5HpmkPv6G-3JQuMc2B329WA1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/us/seattle").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "US").setTargeting("Area", "Seattle"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?636994461934578735"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but dark desktop-only desktop-wide-only" id="nav-link"><a href="https://www.doorsopen.co/#utm_source=RA&amp;utm_medium=Header-link" target="_blank"><span>Music Jobs</span></a></li>
# <li class="but arrow-down temp login" id="profile">Login / Register</li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div><div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mPhotos"><a ga-event-action="Photos" ga-event-category="nav" ga-on="click" href="/photos.aspx">
# Photos</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mNewTracks"><a ga-event-action="New Tracks" ga-event-category="nav" ga-on="click" href="/tracks">
# New Tracks</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
#  DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=LgsUcPmpTNV0nNOC1wz8x1BB-Dw1HtLyGXWG1QRD1nI1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=zXRtQUPi0KqTuYe67D_Me-2Jb8hgyD_oH9FKsjTnVQA1"></script>
# <script src="/bundles/analytics-js?v=GRbOA-5b5S00wbAK8zMczxQRPgbblgKCy7f2bir0h281"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./seattle?cc=us&amp;an=seattle" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="otGvuKhDLP5gTv/3u3LWHc97Sw1t/NUQxAoDO7SVOjqmKOEQ/UgfQxckLMfXLINuf+YsKs/B3YX+ppviR0fFzNRaors="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in Seattle</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Thu, 25 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275558"><img class="nohide" src="/images/events/flyer/2019/7/us-0725-1275558-list.jpg"/></a>
# <p class="counter nohide">
# <span>13</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275558">
# <h1>
# Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jame$ Ervin, Cat Claw
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=84493">The Monkey Loft</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 27 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1280694"><img class="nohide" src="/images/events/flyer/2019/7/us-0727-1280694-list.jpg"/></a>
# <p class="counter nohide">
# <span>10</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1280694">
# <h1>
# Diggin' Deep 12hr with Doc Martin Sublevel Live
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=84493">The Monkey Loft</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Thu, 1 Aug 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275564"><img class="nohide" src="/images/events/flyer/2019/8/us-0801-1275564-list.jpg"/></a>
# <p class="counter nohide">
# <span>6</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275564">
# <h1>
# Deck'd Out #7 Cascadia NW Decompression with Nitin (TOR) &amp; Manahan
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=84493">The Monkey Loft</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Thu, 8 Aug 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275627"><img class="nohide" src="/images/events/flyer/2019/8/us-0808-1275627-list.jpg"/></a>
# <p class="counter nohide">
# <span>9</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275627">
# <h1>
# Deck'd Out #8 Dance Spirit Live (LA) - DBR Fundraiser
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=84493">The Monkey Loft</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sun, 11 Aug 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1264970"><img class="nohide" src="/images/events/flyer/dj/flyinglotus-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1264970">
# <h1>
# Flying Lotus
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=9459">Showbox SoDo</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sun, 11 Aug 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1260010"><img class="nohide" src="/images/events/flyer/2019/8/us-0811-1260010-list.jpg"/></a>
# <p class="counter nohide">
# <span>3</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1260010">
# <h1>
# Chillography 12 - A Free All Ages Day Party in the Park
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Seattle
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Thu, 15 Aug 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275628"><img class="nohide" src="/images/events/flyer/2019/8/us-0815-1275628-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275628">
# <h1>
# Deck'd Out #9 Seattle Church of House Music Takeover
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=84493">The Monkey Loft</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 17 Aug 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1290662"><img class="nohide" src="/images/events/flyer/2019/8/us-0817-1290662-list.jpg"/></a>
# <p class="counter nohide">
# <span>14</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1290662">
# <h1>
# THIS! 12 Hour with Osunlade
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=84493">The Monkey Loft</a>
# </p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>
# <script>
#                             googleAnalytics.sendEventDataOnLoad('events-page', 'popular-events-loaded');
#                        </script>
# </section>
# <section class="iOSOnly content">
# <ul class="phones">
# <li class="f12 pb4 grey">Want RA listings on your mobile?</li>
# <li>
# <div class="but"><a href="https://itunes.apple.com/app/apple-store/id981952703?mt=8">Download the RA Guide</a></div>
# </li>
# </ul>
# </section>
# <div class="banner clearfix">
# <div id="pnlECTOSlot1" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-0"></div>
# </div>
# </div>
# </li>
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/seattle/week/2019-07-15">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/seattle/week/2019-07-29">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="2"/>
# <span>US</span><input id="country-name" type="hidden" value="United States of America"/><ul class="links" style="display: none;"><li data-id="7"><a href="/events">Canada</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="20"><a href="/events">Italy</a></li><li data-id="6"><a href="/events">Netherlands</a></li><li data-id="5"><a href="/events">Spain</a></li><li data-id="3"><a href="/events">United Kingdom</a></li><li class="selected" data-id="2"><a href="/events">United States of America</a></li><li data-id="0"><a href="/events">------------</a></li><li data-id="99"><a href="/events">Albania</a></li><li data-id="125"><a href="/events">Algeria</a></li><li data-id="113"><a href="/events">Andorra</a></li><li data-id="127"><a href="/events">Angola</a></li><li
span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=46&amp;v=day&amp;mn=7&amp;yr=2019&amp;dy=27"><span>Sat, 27 Jul 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time dateti ...
# </ul>
# </div>
# <div class="fl col2" style="padding-top: 88px;">
# <div class="pr8 sticky">
# <section id="calendar">
# <div class="h-align">
# <h1 class="heading">Calendar</h1>
# </div>
# <div id="calendar-inner">
# <select id="ddlCalendarMonth" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarMonth" style="width:104px;">
# <option value="12">December</option>
# <option value="11">November</option>
# <option value="10">October</option>
# <option value="9">September</option>
# <option value="8">August</option>
# <option selected="selected" value="7">July</option>
# <option value="6">June</option>
# <option value="5">May</option>
# <option value="4">April</option>
# <option value="3">March</option>
# <option value="2">February</option>
# <option value="1">January</option>
# </select>
# <select id="ddlCalendarYear" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarYear">
# <option selected="selected" value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# </select>
# <select id="ddlCalendarType" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarType" style="width:104px;">
# <option value="day">By day</option>
# <option selected="selected" value="week">By week</option>
# <option value="month">By month</option>
# </select>
# <input id="hfCalendarDayOfWeek" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$hfCalendarDayOfWeek" type="hidden" value="23"/>
# <table><tr><th>Sun</th><th>Mon</th><th>Tue</th><th>Wed</th><th>Thu</th><th>Fri</th><th>Sat</th></tr><tr><td><a class="day-off" href="/events/us/seattle/week/2019-06-30">30</a></td><td><a href="/events/us/seattle/week/2019-07-01">1</a></td><td><a href="/events/us/seattle/week/2019-07-02">2</a></td><td><a href="/events/us/seattle/week/2019-07-03">3</a></td><td><a href="/events/us/seattle/week/2019-07-04">4</a></td><td><a href="/events/us/seattle/week/2019-07-05">5</a></td><td><a href="/events/us/seattle/week/2019-07-06">6</a></td></tr><tr><td><a href="/events/us/seattle/week/2019-07-07">7</a></td><td><a href="/events/us/seattle/week/2019-07-08">8</a></td><td><a href="/events/us/seattle/week/2019-07-09">9</a></td><td><a href="/events/us/seattle/week/2019-07-10">10</a></td><td><a href="/events/us/seattle/week/2019-07-11">11</a></td><td><a href="/events/us/seattle/week/2019-07-12">12</a></td><td><a href="/events/us/seattle/week/2019-07-13">13</a></td></tr><tr><td><a href="/events/us/seattle/week/2019-07-14">14</a></td><td><a href="/events/us/seattle/week/2019-07-15">15</a></td><td><a href="/events/us/seattle/week/2019-07-16">16</a></td><td><a href="/events/us/seattle/week/2019-07-17">17</a></td><td><a href="/events/us/seattle/week/2019-07-18">18</a></td><td><a href="/events/us/seattle/week/2019-07-19">19</a></td><td><a href="/events/us/seattle/week/2019-07-20">20</a></td></tr><tr><td><a href="/events/us/seattle/week/2019-07-21">21</a></td><td><a href="/events/us/seattle/week/2019-07-22">22</a></td><td><span class="day-current">23</span></td><td><a href="/events/us/seattle/week/2019-07-24">24</a></td><td><a href="/events/us/seattle/week/2019-07-25">25</a></td><td><a href="/events/us/seattle/week/2019-07-26">26</a></td><td><a href="/events/us/seattle/week/2019-07-27">27</a></td></tr><tr><td><a href="/events/us/seattle/week/2019-07-28">28</a></td><td><a href="/events/us/seattle/week/2019-07-29">29</a></td><td><a href="/events/us/seattle/week/2019-07-30">30</a></td><td><a href="/events/us/seattle/week/2019-07-31">31</a></td><td><a class="day-off" href="/events/us/seattle/week/2019-08-01">1</a></td><td><a class="day-off" href="/events/us/seattle/week/2019-08-02">2</a></td><td><a class="day-off" href="/events/us/seattle/week/2019-08-03">3</a></td></tr></table>
# </div>
# <script type="text/javascript">
# 		$("#ddlCalendarMonth, #ddlCalendarYear, #ddlCalendarType").change(function () {
#             var aSearch = location.search.indexOf("&") > 0
#                 ? location.search.split('&')
#                 : "";
#
# 			var sQueryString;
#
#             var month = $('#ddlCalendarMonth').val().length === 2
#                 ? $('#ddlCalendarMonth').val()
#                 : "0" + $('#ddlCalendarMonth').val();
#
#             var day = $('#hfCalendarDayOfWeek').val().length === 2
#                 ? $('#hfCalendarDayOfWeek').val()
#                 : "0" + $('#hfCalendarDayOfWeek').val();
#
#             var area = $('#liArea span').text().replace(/[^A-Z0-9]/ig, '').toLowerCase() === 'all'
#                 ? ""
#                 : $('#liArea span').text().replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/";
#
#             var country = area === ''
#                 ? $('#country-name').val()
#                 : $('#liCountry span').text()
#
# 			sQueryString = "/events/"
#                 + country.replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/"
#                 + area
#                 + $('#ddlCalendarType').val() + "/"
# 				+ $('#ddlCalendarYear').val() + "-"
#                 + month + "-"
# 				+ day;
#
# 			location.href = sQueryString;
# 		});
# 	</script>
# </section>
# <div class="banner">
# <div id="pnlMPU">
# <div class="ad" id="div-gpt-ad-1452773484957-7" style="width: 300px; min-height: 250px; padding-bottom: 10px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fl col2 h-align-toplist">
# <div class="mr8">
# <section class="top-list generic events" id="toplist">
# <h1 class="heading">Top Seattle clubs</h1>
# <ul>
# <li><a ga-event-action="Kremwerk" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=88733">Kremwerk</a> /</li><li><a ga-event-action="Re-Bar" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5613">Re-Bar</a> /</li><li><a ga-event-action="Q Nightclub" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=68203">Q Nightclub</a> /</li><li><a ga-event-action="Neumos" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=3715">Neumos</a> /</li><li><a ga-event-action="The Monkey Loft" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=84493">The Monkey Loft</a> /</li><li><a ga-event-action="Chop Suey" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=4383">Chop Suey</a> /</li><li><a ga-event-action="The Showbox" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=11363">The Showbox</a> /</li><li><a ga-event-action="Nectar Lounge" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=2730">Nectar Lounge</a> /</li><li><a ga-event-action="Baltic Room" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=6064">Baltic Room</a> /</li><li><a ga-event-action="Lo-Fi Gallery" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=10003">Lo-Fi Gallery</a> /</li><li><a ga-event-action="Trinity" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=2813">Trinity</a> /</li><li><a ga-event-action="Club Contour" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=2042">Club Contour</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=46">More Seattle clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Ibiza" ga-event-category="top-regions" ga-on="click" href="/guide/es/ibiza">Ibiza, ES</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="Los Angeles" ga-event-category="top-regions" ga-on="click" href="/guide/us/losangeles">Los Angeles, US</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Miami" ga-event-category="top-regions" ga-on="click" href="/guide/us/miami">Miami, US</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/greece">Greece</a> /</li><li><a ga-event-action="San Francisco" ga-event-category="top-regions" ga-on="click" href="/guide/us/sanfrancisco">San Francisco, US</a> /</li><li><a ga-event-action="Lisbon" ga-event-category="top-regions" ga-on="click" href="/guide/pt/lisbon">Lisbon, PT</a> /</li><li><a ga-event-action="Chubu" ga-event-category="top-regions" ga-on="click" href="/guide/jp/chubu">Chubu, JP</a> /</li><li><a ga-event-action="Montreal" ga-event-category="top-regions" ga-on="click" href="/guide/ca/montreal">Montreal, CA</a> /</li><li><a ga-event-action="Melbourne" ga-event-category="top-regions" ga-on="click" href="/guide/au/melbourne">Melbourne, AU</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="Washington DC" ga-event-category="top-regions" ga-on="click" href="/guide/us/washingtondc">Washington DC, US</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/seattle/week/2019-07-15">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/seattle/week/2019-07-29">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 17 Jul 2019</p>
# <a href="/news/44099">
# <img class="thumb" src="/images/news/2019/four-tet-dreamer-new-track.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/
</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 16 Jul 2019</p>
# <a href="/news/44096">
# <img class="thumb" src="/images/news/2019/loraine-james-jase-cooper-for-you-and-i-hyperdub-album-press-photo.jpeg"/>
# </a>
# <p class="comments light">
# <a href="/news/44096/?comments=1">Post a comment</a>
# </p><a href="/news/44096">
# <h1>Loraine James to debut on Hyperdub with new album, For You And I</h1>
# </a>
# <p class="copy">The London artist's next LP lands September 20th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 18 Jul 2019</p>
# <a href="/news/44118">
# <img class="thumb" src="/images/news/2019/sustain-release-2019-final-lineup.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44118/?comments=1">Post a comment</a>
# </p><a href="/news/44118">
# <h1>Sustain-Release completes lineup for 2019</h1>
# </a>
# <p class="copy">The US festival has added Batu, Cashu, DJ Python, Hiro Kone and more for its sixth edition.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 17 Jul 2019</p>
# <a href="/news/44112">
# <img class="thumb" src="/images/news/2019/spiritland-broadcast-truck-inside-desk.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44112/?comments=1">Post a comment</a>
# </p><a href="/news/44112">
# <h1>London's Spiritland to head out on the road with new broadcast vehicle, Spiritland One</h1>
# </a>
# <p class="copy">Known for listening bars in King's Cross and Royal Festival Hall, Spiritland's new project aims to make audiophile production more accessible.</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2019 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
events_container = soup.find('div', {'id':'event-listing'})

# %%
events_container
# Out:
# <div class="fl col4" id="event-listing">
# <ul class="list" id="items">
# <li><p class="eventDate date"><a href="/events.aspx?ai=46&amp;v=day&amp;mn=7&amp;yr=2019&amp;dy=25"><span>Thu, 25 Jul 2019 /</span></a></p></li><li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1275558#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-07-25T00:00" itemprop="startDate">2019-07-25T00:00</time></span><a href="/events/1275558"><img height="76" src="/images/events/flyer/2019/7/us-0725-1275558-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1275558" itemprop="url" title="Event details of Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jame$ Ervin, Cat Claw">Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jame$ Ervin, Cat Claw</a> <span>at <a href="/club.aspx?id=84493">The Monkey Loft</a></span></h1><div class="grey event-lineup">Pezzner, Riz Rolings, Jame$ Ervin, Cat Claw</div><p class="attending"><span>13</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-25T00:00" itemprop="startDate">2019-07-25T00:00</time></span><a href="/events/1278396"><img height="76" src="/images/events/flyer/2019/7/us-0725-1278396-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1278396" itemprop="url" title="Event details of Field Trip 81: Fehrplay">Field Trip 81: Fehrplay</a> <span>at <a href="/club.aspx?id=68203">Q Nightclub</a></span></h1><div class="grey event-lineup">Fehrplay</div><p class="attending"><span>3</span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=46&amp;v=day&amp;mn=7&amp;yr=2019&amp;dy=26"><span>Fri, 26 Jul 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-26T00:00" itemprop="startDate">2019-07-26T00:00</time></span><a href="/events/1280667"><img height="76" src="/images/events/flyer/2019/7/us-0726-1280667-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1280667" itemprop="url" title="Event details of Shook: One Year Anniversary with TMSV, A.Fruit &amp; Sigrah">Shook: One Year Anniversary with TMSV, A.Fruit &amp; Sigrah</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a></span></h1><div class="grey event-lineup">TMSV, A.Fruit, Sigrah</div><p class="attending"><span>1</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-26T00:00" itemprop="startDate">2019-07-26T00:00</time></span><a href="/events/1285655"><img height="76" src="/images/events/flyer/2019/7/us-0726-1285655-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1285655" itemprop="url" title="Event details of 1luv presents: Franklyn Watts: Aundrea: Rhett: Buckmode">1luv presents: Franklyn Watts: Aundrea: Rhett: Buckmode</a> <span>at <a href="/club.aspx?id=84493">The Monkey Loft</a></span></h1><div class="grey event-lineup">♫♪♫♪ The Evenings Beat Conductors ♫♪♫♪, RHETT &amp; BUCKMODE ★ ★ ★ ★ 10pm – 1am, FRANKLYN WATTS ★ ★ ★ ★ ★ ★ ★ 1am – 3am, AUNDREA ★ ★ ★ ★ ★ ★★ ★★ ★ 3am – 4am</div><p class="attending"><span>1</span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=46&amp;v=day&amp;mn=7&amp;yr=2019&amp;dy=27"><span>Sat, 27 Jul 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time dateti ...
# </ul>
# </div>

# %%
events = events_container.findAll('article')

# %%
events[0]
# Out:
# <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1275558#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-07-25T00:00" itemprop="startDate">2019-07-25T00:00</time></span><a href="/events/1275558"><img height="76" src="/images/events/flyer/2019/7/us-0725-1275558-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1275558" itemprop="url" title="Event details of Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jame$ Ervin, Cat Claw">Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jame$ Ervin, Cat Claw</a> <span>at <a href="/club.aspx?id=84493">The Monkey Loft</a></span></h1><div class="grey event-lineup">Pezzner, Riz Rolings, Jame$ Ervin, Cat Claw</div><p class="attending"><span>13</span> Attending</p></div></article>

# %%
event_names = [event.find('a').contents[0] for event in events]

# %%
#find name
events[0].find('h1').find('a').contents[0]
# Out:
# "Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jame$ Ervin, Cat Claw"

# %%
#find venue
events[0].find('h1').find('span').find('a').contents[0]
# Out:
# 'The Monkey Loft'

# %%
#find line-up
events[0].find('div', {'class':'grey event-lineup'}).contents[0]
# Out:
# 'Pezzner, Riz Rolings, Jame$ Ervin, Cat Claw'

# %%
#find date
events[0].findAll('span')[0].find('time').contents[0][:10]
# Out:
# '2019-07-25'

# %%
#find attendees
events[0].findAll('span')[-1].contents[0]
# Out:
# '13'

# %%
event_names = [event.find('h1').find('a').contents[0] for event in events]

# %%
event_venues = [event.find('h1').find('span').find('a').contents[0] for event in events]

# %%
event_line_ups = [event.find('div', {'class':'grey event-lineup'}).
                  contents[0] for event in events]

# %%
event_dates = [event.findAll('span')[0].find('time').contents[0][:10] for event in events]

# %%
events[-1].findAll('span')[0].find('a') is None
# Out:
# True

# %%
attendees = [int(event.findAll('span')[-1].contents[0]) 
                 if len(event.findAll('span'))==3 else 0 for event in events]

# %%
attendees
# Out:
# [13, 3, 1, 1, 10, 3, 0]

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
#for seattle
def scrape_events(events_page_url):
    #Your code here
    html_page = requests.get(events_page_url) 
    soup = BeautifulSoup(html_page.content, 'html.parser') 
    
    events_container = soup.find('div', {'id':'event-listing'})
    events_info = events_container.findAll('article')
    
    event_names = [event.find('h1').find('a').contents[0] 
                   for event in events_info]
    event_venues = [event.find('h1').find('span').find('a').contents[0] 
                    if event.find('h1').find('span').find('a') is not None 
                    else 'TBD'
                    for event in events_info]
    event_dates = [event.findAll('span')[0].find('time').contents[0][:10] 
                   for event in events_info]
    event_attendees = [int(event.findAll('span')[-1].contents[0]) 
                 if len(event.findAll('span'))==3 else 0 for event in events_info]
    
    df = pd.DataFrame([event_names, event_venues, event_dates, event_attendees]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    
    return df

# %%
event_df = scrape_events('https://www.residentadvisor.net/events/us/seattle')

# %%
event_df
# Out:
#                                           Event_Name            Venue  \
# 0  Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jam...  The Monkey Loft
# 1                            Field Trip 81: Fehrplay      Q Nightclub
# 2  Shook: One Year Anniversary with TMSV, A.Fruit...         Kremwerk
# 3  1luv presents: Franklyn Watts: Aundrea: Rhett:...  The Monkey Loft
# 4    Diggin' Deep 12hr with Doc Martin Sublevel Live  The Monkey Loft
# 5                            Secondnature x Bassiani         Kremwerk
# 6  27 Re-bar presents Howell St Irregulars - Theo...           Re-Bar
#
#    Event_Date Number_of_Attendees
# 0  2019-07-25                  13
# 1  2019-07-25                   3
# 2  2019-07-26                   1
# 3  2019-07-26                   1
# 4  2019-07-27                  10
# 5  2019-07-27                   3
# 6  2019-07-27                   1

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
'https://www.residentadvisor.net'+soup.find('li', {'id':'liNext'}).find('a').attrs['href']
# Out:
# 'https://www.residentadvisor.net/events/us/seattle/week/2019-07-29'

# %%
def next_page(url):
    #Your code here
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    base_url = 'https://www.residentadvisor.net'
    href_url = soup.find('li', {'id':'liNext'}).find('a').attrs['href']
    
    next_page_url = base_url + href_url
    
    return next_page_url

# %%
next_page('https://www.residentadvisor.net/events/us/seattle/week/2019-07-30')
# Out:
# 'https://www.residentadvisor.net/events/us/seattle/week/2019-08-06'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
seattle_events_df = pd.DataFrame(columns = ["Event_Name", "Venue", 
                                            "Event_Date", "Number_of_Attendees"])
seattle_events_df
# Out:
# Empty DataFrame
# Columns: [Event_Name, Venue, Event_Date, Number_of_Attendees]
# Index: []

# %%
seattle_events_df
# Out:
#                                           Event_Name            Venue  \
# 0  Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jam...  The Monkey Loft
# 1                            Field Trip 81: Fehrplay      Q Nightclub
# 2  Shook: One Year Anniversary with TMSV, A.Fruit...         Kremwerk
# 3  1luv presents: Franklyn Watts: Aundrea: Rhett:...  The Monkey Loft
# 4    Diggin' Deep 12hr with Doc Martin Sublevel Live  The Monkey Loft
# 5                            Secondnature x Bassiani         Kremwerk
# 6  27 Re-bar presents Howell St Irregulars - Theo...           Re-Bar
# 0  Deck'd Out #7 Cascadia NW Decompression with N...  The Monkey Loft
# 1                          Haüsed x Depth: B. Traits         Kremwerk
# 2                               Field Trip 82: Nukid      Q Nightclub
# 3         Bunker 122 X Depth presents USUK W Mark Eg  The Underground
# 4                                  Pop Secret: Hucci      Q Nightclub
# 5                          Re-bar presents Noah Pred           Re-Bar
#
#    Event_Date Number_of_Attendees
# 0  2019-07-25                  13
# 1  2019-07-25                   3
# 2  2019-07-26                   1
# 3  2019-07-26                   1
# 4  2019-07-27                  10
# 5  2019-07-27                   3
# 6  2019-07-27                   1
# 0  2019-08-01                   6
# 1  2019-08-01                   2
# 2  2019-08-01                   1
# 3  2019-08-02                   3
# 4  2019-08-02                   1
# 5  2019-08-02                   0

# %%
events_url = 'https://www.residentadvisor.net/events/us/seattle'

for i in range(0,20):
    
    temp_df = scrape_events(events_url)
    seattle_events_df = pd.concat([seattle_events_df, temp_df])
    
    events_url = next_page(events_url)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-170-187c4e2e4dc6> in <module>()
#       6     seattle_events_df = pd.concat([seattle_events_df, temp_df])
#       7
# ----> 8     events_url = next_page(events_url)
#
# <ipython-input-151-37d7b8781d04> in next_page(url)
#       4     soup = BeautifulSoup(html_page.content, 'html.parser')
#       5     base_url = 'https://www.residentadvisor.net'
# ----> 6     href_url = soup.find('li', {'id':'liNext'}).find('a').attrs['href']
#       7
#       8     next_page_url = base_url + href_url
#
# KeyError: 'href'

# %%
seattle_events_df
# Out:
#                                           Event_Name            Venue  \
# 0  Deck'd Out #6 Stayin' Alive: Pezzner, Riz, Jam...  The Monkey Loft
# 1                            Field Trip 81: Fehrplay      Q Nightclub
# 2  Shook: One Year Anniversary with TMSV, A.Fruit...         Kremwerk
# 3  1luv presents: Franklyn Watts: Aundrea: Rhett:...  The Monkey Loft
# 4    Diggin' Deep 12hr with Doc Martin Sublevel Live  The Monkey Loft
# 5                            Secondnature x Bassiani         Kremwerk
# 6  27 Re-bar presents Howell St Irregulars - Theo...           Re-Bar
# 0  Deck'd Out #7 Cascadia NW Decompression with N...  The Monkey Loft
# 1                          Haüsed x Depth: B. Traits         Kremwerk
# 2                               Field Trip 82: Nukid      Q Nightclub
# 3         Bunker 122 X Depth presents USUK W Mark Eg  The Underground
# 4                                  Pop Secret: Hucci      Q Nightclub
# 5                          Re-bar presents Noah Pred           Re-Bar
# 0  Deck'd Out #8 Dance Spirit Live (LA) - DBR Fun...  The Monkey Loft
# 1                       Field Trip 83: Nero (DJ Set)      Q Nightclub
# 2  Noise Complaint's 3rd Bday feat. Mija & Golf Clap         Kremwerk
# 3                            Pop Secret: Mr. Carmack      Q Nightclub
# 4                                       Flying Lotus     Showbox SoDo
# 5  Chillography 12 - A Free All Ages Day Party in...              TBD
# 0  Deck'd Out #9 Seattle Church of House Music Ta...  The Monkey Loft
# 1                           Field Trip 84: Shift K3Y      Q Nightclub
# 2  Deck'd Out #9 Seattle Church of House Music Ta...  The Monkey Loft
# 3                        THIS! 12 Hour with Osunlade  The Monkey Loft
# 4                              ORA Nightclub Seattle              Ora
# 0  Deck'd Out #10 David Scuba (Superfreq, Desert ...  The Monkey Loft
# 1  Deck'd Out #10 David Scuba (Superfreq, Desert ...  The Monkey Loft
# 2                  Sleepless & Sub 49 present: Xcrpt     Club Contour
# 0  Deck'd Out #11 Paolo Rocco (Montreal) with Viv...  The Monkey Loft
# 1                              Field Trip 86: Attlas      Q Nightclub
# 2      Depth 3-Year: Zenker Brothers - 10 PM - 10 AM         Kremwerk
# 0  Deck'd Out #12 Closing Party with J.Phlip (SF)...  The Monkey Loft
# 0                                            Janeret              TBD
# 0   Fleetmac Wood presents Gold Dust Disco - Seattle         Kremwerk
# 0                            Field Trip 92: JackLNDN      Q Nightclub
# 0       Field Trip 96: Chris Lorenzo (Open-to-Close)      Q Nightclub
#
#    Event_Date Number_of_Attendees
# 0  2019-07-25                  13
# 1  2019-07-25                   3
# 2  2019-07-26                   1
# 3  2019-07-26                   1
# 4  2019-07-27                  10
# 5  2019-07-27                   3
# 6  2019-07-27                   1
# 0  2019-08-01                   6
# 1  2019-08-01                   2
# 2  2019-08-01                   1
# 3  2019-08-02                   3
# 4  2019-08-02                   1
# 5  2019-08-02                   0
# 0  2019-08-08                   9
# 1  2019-08-08                   1
# 2  2019-08-09                   3
# 3  2019-08-09                   1
# 4  2019-08-11                   4
# 5  2019-08-11                   0
# 0  2019-08-15                   4
# 1  2019-08-15                   0
# 2  2019-08-16                   4
# 3  2019-08-17                  16
# 4  2019-08-17                   2
# 0  2019-08-22                   4
# 1  2019-08-23                   4
# 2  2019-08-24                   1
# 0  2019-08-29                   2
# 1  2019-08-29                   1
# 2  2019-08-30                   3
# 0  2019-09-05                  13
# 0  2019-09-22                   0
# 0  2019-09-28                   4
# 0  2019-10-10                   1
# 0  2019-11-07                   2

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
